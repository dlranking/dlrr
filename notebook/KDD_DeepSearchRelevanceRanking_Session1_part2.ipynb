# %% [markdown]
# Welcome to Deep Search Relevance Ranking Session1- Part1! 😀
# ### PART 2: VECTOR SPACE MODEL :

# %% [markdown]
# Same as Part I: If you're opening this Notebook on colab, you will probably need to install 🤗 Transformers and 🤗 Datasets. Uncomment the following cell and run it.

# %%
! pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.2.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.19.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: dill<0.3.5 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.7.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.19.2

# %%
import re
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Loading the dataset

# %% [markdown]
# We will use the 🤗 Datasets library to download the data and run our algorithms.
#  - This can be done with the functions load_dataset and load_metric.
#  - We will use XGlue during  all of our sessions: https://huggingface.co/datasets/xglue/viewer/qadsm/

# %%
from datasets import load_dataset, load_metric

# %%
xglue = load_dataset('xglue', 'qadsm')
# Out:
# Reusing dataset x_glue (/root/.cache/huggingface/datasets/x_glue/qadsm/1.0.0/8566eedecd9ab28e01c051c023dadf97bf408e5195f76b06aba70ebd4697ae08)
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
print(xglue)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 100000
#     })
#     validation.en: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 10000
#     })
#     validation.de: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 10000
#     })
#     validation.fr: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 10000
#     })
#     test.en: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 10000
#     })
#     test.de: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 10000
#     })
#     test.fr: Dataset({
#         features: ['query', 'ad_title', 'ad_description', 'relevance_label'],
#         num_rows: 10000
#     })
# })

# %%
xglue['train'].shape
# Out:
# (100000, 4)

# %%
xglue['train'][0:2]  #xglue['train']['ad_title][0:2]
# Out:
# {'ad_description': ['Your New England Cruise Awaits! Holland America Line Official Site.',
#   'Explore Your World with Four Extraordinary Offers.'],
#  'ad_title': ['New England Cruises', 'Holland America Line®'],
#  'query': ['cruise portland maine', 'transportation to cruise port miami'],
#  'relevance_label': [1, 0]}

# %%
xglue['train']['ad_description'][0:2]
# Out:
# ['Your New England Cruise Awaits! Holland America Line Official Site.',
#  'Explore Your World with Four Extraordinary Offers.']

# %%
len(xglue['train']['ad_description'])
# Out:
# 100000

# %% [markdown]
# # Vector Space Model Implementation for Search Ranking

# %% [markdown]
# ### Loading the DataSet , Create Corpus and fit_transform it into TIDF vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = xglue['train']['ad_description']
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())
print(X.shape)
# Out:
# ['00', '000', '0000', '000ft', '000lb', '000m', '000s', '001', '0040', '0065', '00807', '009', '01', '0100', '0125', '016', '0170', '0177', '0183', '0194', '0199', '02', '0201', '0224', '0231', '0267', '0281', '029', '02rx', '03', '037', '0380', '0399', '04', '0404441248', '0406', '0411', '0444', '0458', '0463', '0497', '05', '050', '0502', '0544', '055', '0556', '0576', '0577', '058', '06', '0621', '0637', '0677', '07', '0707', '0714', '0735', '0759', '0767', '0777', '0786', '0798', '08', '0800', '0809', '0814', '0855', '0858', '0872', '0888', '08a', '09', '090', '09030', '0948', '096', '0962', '0963', '09990', '0tterbox', '0x80070424', '10', '100', '1000', '10000', '100000', '10000s', '1000bulbs', '1000cc', '1000ft', '1000mcg', '1000mg', '1000s', '1001', '1003', '1004', '1006', '10067353', '1009', '100cc', '100k', '100m', '100mm', '100oz', '100s', '101', '1013', '102', '10293', '102mbk', '1030', '1031', '104', '1040400', '105', '1050', '1060', '1065', '107', '10750', '1080p', '1082', '1087', '109', '1092', '1095', '1098', '1099', '10bucks', '10gig', '10k', '10mm', '10now', '10offr', '10pm', '10poff', '10r', '10s', '10th', '10x', '10x10', '10x15', '10x20', '10x30', '10x42', '10xl', '11', '110', '1100', '11000', '110000', '1101', '110cc', '110mesh', '111', '1111', '1112', '112', '11224vsr', '11245evs', '11247', '1125', '11250vsr', '11255vsr', '113', '11316evs', '114', '1140', '1144', '1149', '114s', '115', '1156', '1182', '119', '1198', '119m', '11pm', '11th', '12', '120', '1200', '1200a', '12013', '120e', '120f', '120hz', '120in', '120v', '121', '122', '1222', '123', '123findacar', '123inks', '125', '125cc', '126', '127', '1278', '1279', '128', '1282', '128gb', '129', '1295', '1297', '1299', '12c', '12mm', '12oz', '12th', '12v', '12w', '12x20', '12x40', '13', '130', '1300', '131', '1314', '1315', '131k', '132', '1320', '1324', '1328', '1330', '13485', '135', '1350', '1355', '135mm', '1367', '137', '1377', '1384', '139', '13ft', '13k', '13yrs', '14', '140', '1400', '140mm', '141', '1410', '142', '143', '144', '1443', '145', '1456', '146', '1465', '147', '1474', '1479', '148', '149', '1490', '1499', '14k', '14mm', '14th', '14x18x1', '15', '150', '1500', '15000', '1500mg', '1500s', '1503', '150cc', '150k', '150s', '1520', '153', '1541', '15432', '1554', '156', '1563', '157', '1574', '1575a', '158', '158116', '159', '1592', '15k', '15mm', '15off', '15save100', '15th', '15x', '16', '160', '1600', '1602', '161', '1628', '1648', '165', '1650', '166', '1666', '1667', '167', '1678', '168', '169', '1690', '1699', '16gb', '16mm', '16t', '16th', '16w', '16x25x5', '17', '170', '1700', '17000', '1709', '1715', '173', '1738', '175', '1755', '1767', '177', '1778', '1785', '179', '1793', '1796', '17c', '17mm', '17pc', '17th', '17x22', '17x8', '18', '180', '1800', '18000', '18003918402', '1800es', '1800flowers', '181', '1826', '183', '184', '1844', '1846', '1847', '1851', '1855', '1859', '186', '1861', '1863', '1865', '1866', '187', '1870', '1877', '1878', '1886', '1887', '1888', '189', '1893', '1894', '1895', '1896', '1899', '18k', '18th', '18v', '18x24x4', '19', '190', '1901', '1909', '1911', '1912', '1918', '1920', '1920s', '1922', '19240', '1925', '1926', '1927', '1928', '193', '1930', '1930s', '1931', '1932', '1933', '1938', '1939', '194', '1940', '1942', '1943', '1944', '1946', '1947', '1948', '1949', '195', '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '196', '1960', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '19776', '1978', '1979', '198', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1989', '199', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '19th', '1br', '1click', '1d', '1gb', '1k', '1l', '1lb', '1m', '1mm', '1mp', '1pc', '1pm', '1r5', '1st', '1tb', '1yr', '20', '200', '2000', '200000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '200c ...
# (100000, 24169)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
#loading basic packages
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
stop_words = set(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# # Preprocessing Functions
# ### Tokenizing, removeing extra space, puncatuations, removing stop words and stemming

# %%
# this function returns a list of tokenized and stemmed words of any text
def rem_pun(doc_text):
    return re.sub(r'[^\w\s]', '', doc_text)
  
def rem_digits(doc_text):
    return re.sub(r'[0-9]+', '', doc_text)

def del_extra_spaces(doc_text):
    return  " ".join(doc_text.split())

def get_tokenized_list(doc_text):
    tokens = nltk.word_tokenize(doc_text)
    return tokens


def word_stemmer(token_list):
  ps = nltk.stem.PorterStemmer()
  stemmed = []
  for words in token_list:
    stemmed.append(ps.stem(words))
  return stemmed

# %%
def remove_stopwords(doc_text):
  cleaned_text = []
  for words in doc_text:
    if words not in stop_words:
      cleaned_text.append(words)
  return cleaned_text

# %%
#Check for single ad_description
print("ad_description example =",corpus[10])
repun_corpus_1 = rem_pun(corpus[10])
print("after removing puntucation ad_description=",repun_corpus_1)
repun_corpus_1 = rem_digits(repun_corpus_1)
pre_corpuse_1 =del_extra_spaces(repun_corpus_1)
tokens = get_tokenized_list(pre_corpuse_1)
print("WORD TOKENS:")
print(tokens)
doc_text = remove_stopwords(tokens)
print("\nAFTER REMOVING STOPWORDS:")
print(doc_text)
print("\nAFTER PERFORMING THE WORD STEMMING::")
doc_text = word_stemmer(doc_text)
doc_text
# Out:
# corpus[2]= Indulge in your Ideal Cruise. View Special Offers at the Offical Site!
# repun_corpus_1= Indulge in your Ideal Cruise View Special Offers at the Offical Site
# WORD TOKENS:
# ['Indulge', 'in', 'your', 'Ideal', 'Cruise', 'View', 'Special', 'Offers', 'at', 'the', 'Offical', 'Site']
#
# AFTER REMOVING STOPWORDS:
# ['Indulge', 'Ideal', 'Cruise', 'View', 'Special', 'Offers', 'Offical', 'Site']
#
# AFTER PERFORMING THE WORD STEMMING::
# ['indulg', 'ideal', 'cruis', 'view', 'special', 'offer', 'offic', 'site']

# %%
doc_ = ' '.join(doc_text)
doc_
# Out:
# 'indulg ideal cruis view special offer offic site'

# %% [markdown]
# #Performing Preprocessing on our Corpus

# %%
cleaned_corpus = []
for doc in corpus:
  repun_corpus = rem_pun(doc)
  repun_corpus = rem_digits(repun_corpus)
  pre_corpuse =del_extra_spaces(repun_corpus)
  tokens = get_tokenized_list(pre_corpuse)
  doc_text = remove_stopwords(tokens)
  doc_text  = word_stemmer(doc_text)
  doc_text = ' '.join(doc_text)
  cleaned_corpus.append(doc_text)
cleaned_corpus
# Out:
# ['your new england cruis await holland america line offici site',
#  'explor your world four extraordinari offer',
#  'cruis your own privat island In caribbean learn more now',
#  'sign Up offer explor caribbean holland america line',
#  'offici site sign Up special new england cruis offer today',
#  'your canada cruis await holland america line offici site',
#  'beauti jewelri At low price order ship free from zale',
#  'learn holland america ship holland america line offici site',
#  'offici websit sign Up today for special offer cruis',
#  'sign Up for special offer take virtual tour watch video more',
#  'indulg ideal cruis view special offer offic site',
#  'offici site find your ideal cruis view special offer more',
#  'fine jewelri At unbeat price plu free ship On order',
#  'fine jewelri At unbeat price plu free ship On order',
#  'fine ring At unbeat price plu free ship On order',
#  'free ship qualifi order low price babi R Us',
#  'shop latest velvet jacket',
#  'ador shirt bib romper person free shop now save',
#  'person coffe mug for mom great gift idea free engrav',
#  'welcom visitor custom style great given gift',
#  'buy custom golf tee free person fast SH',
#  'free ship qualifi order buy templ univers amazon',
#  'free ship qualifi order buy robot art amazon',
#  'low price best seller new releas classic',
#  'save perfect toy all age free ship qualifi order',
#  'free day ship w amazon prime low price million book',
#  'low price best seller new releas classic',
#  'free day ship w amazon prime low price million book',
#  'free ship qualifi order buy ellen degener amazon',
#  'free day ship w amazon prime low price million book',
#  'save kid book age stage new releas classic',
#  'free day ship w amazon prime low price million book',
#  'low price sofa loveseat free ship qualifi order',
#  'million titl new use free ship qualifi order',
#  'free day ship w amazon prime low price million book',
#  'free ship qualifi order buy duve amazon',
#  'low price million book free ship qualifi order',
#  'free ship qualifi order buy liver doctor amazon',
#  'stay ahead curv busi invest book',
#  'free day ship w amazon prime low price million book',
#  'enjoy unlimit instant stream TV movi anywher anytim',
#  'onestop shop movi TV free ship qualifi order',
#  'million titl new use free ship qualifi order',
#  'everi cuisinart part accesori part order ship free',
#  'play free casino money',
#  'play free casino money',
#  'free ship qualifi order buy golf ball marker amazon',
#  'low price purpos driven Of life free ship qualifi order',
#  'low price best seller new releas classic',
#  'free day ship w amazon prime low price million book',
#  'free ship qualifi order buy that I may know him amazon',
#  'free day ship w amazon prime low price million book',
#  'save book low price sport train outdoor more',
#  'free day ship w amazon prime low price million book',
#  'free ship qualifi order buy purposedriven life amazon',
#  'free ship qualifi order low price new use music',
#  'million titl new use free ship qualifi order',
#  'save kid book age stage new releas classic',
#  'free day ship w amazon prime low price million book',
#  'the first antiviru cloud simpl light secur buy now',
#  'download new panda cloud US year',
#  'now panda internet secur discount get now',
#  'your antiviru incred light with panda cloud technolog',
#  'fast effici protect includ free technic support',
#  'your antiviru incred light with panda cloud technolog',
#  'for you best multidevic protect',
#  'first antiviru multidevic take advantag offer panda secur',
#  'free ship qualifi order buy cut past amazon',
#  'free ship qualifi order low price new use music',
#  'free day ship w amazon prime low price million book',
#  'free ship qualifi order buy christian calendar amazon',
#  'low price best seller new releas classic',
#  'free day ship w amazon prime low price million book',
#  'stay ahead curv busi invest book',
#  'free day ship w amazon prime low price million book',
#  'buy travel guid travel tale amazon explor world save',
#  'save new use mysteri book free ship qualifi order',
#  'free day ship w amazon prime low price million book',
#  'million titl new use free ship qualifi order',
#  'free UK deliveri save order now finest gourmet hamper from',
#  'free UK deliveri save order now finest gourmet hamper from',
#  'low price new use music free ship qualifi order',
#  'million titl new use free ship qualifi order',
#  'free ship qualifi order buy bill Me later amazon',
#  'low price saint theres free ship qualifi order',
#  'book satisfi anyon new learner comput geek',
#  'stay ahead curv busi invest book',
#  'free day ship w amazon prime low price million book',
#  'stay ahead curv busi invest book',
#  'low price new use music free ship qualifi order',
#  'book everi foodi gourmet chef',
#  'low price best seller new releas classic',
#  'free ship qualifi order buy simciti amazon',
#  'book everi foodi gourmet chef',
#  'free ship qualifi order buy saq amazon',
#  'free ship qualifi order buy popular product amazon',
#  'shop board game collect card game more',
#  'free ship qualifi order buy E amazon',
#  'cost effect secur open park storag close citi centr',
#  'origin proven treatment best price immedi dispatch',
#  'wholesal case price bulk food item huge stock quick ship',
#  'busi get quick easi loan lender earn invest',
#  'secur storag for plymouth home busi low cost flexibl term',
#  'backyard structur yoga camp workshop more call Us',
#  'fullfeatur backup softwar top rate freewar avail',
#  'dune find lowest price',
#  'Up To off etni shoe compar and save',
#  'Up To off engin model compar and save',
#  'Up To off emerson electr compar and save',
#  'Up To off electr suppli compar and save',
#  'Up To off avocado tree compar and save',
#  'Up To off auto saturn compar and save',
#  'Up To off auto paint compar and save',
#  'Up To off arm massag compar and save',
#  'save On arden elizabeth love true compar and save',
#  'Up To off archeri compar and save',
#  'Up To off appl honey compar and save',
#  'Up To off abit and motherboard compar and save',
#  'Up To off A purpos driven life compar and save',
#  'Up To off A letter from santa compar and save',
#  'trivago save Up To hotel find ideal hotel la vega',
#  'Up To off use outboard johnson compar and save',
#  'Up To off johnson use compar and save',
#  'Up To off ultraviolet light compar and save',
#  'Up To off vintag motorcycl compar and save',
#  'Up To off vic card compar and save',
#  'Up To off johnni blue compar and save',
#  'save On jigsaw puzzl On line compar and save',
#  'Up To off jewerli factori compar and save',
#  'Up To off www pandora com compar and save',
#  'Up To off wrestl sweatshirt compar and save',
#  'Up To off well water compar and save',
#  'Up To off wed chair compar and save',
#  'Up To off water plant compar and save',
#  'Up To off water well compar and save',
#  'Up To off water from well compar and save',
#  'Up To off initi handkerchief compar and save',
#  'Up To off kitchen uniform compar and save',
#  'Up To off kid road bike compar and save',
#  'Up To off long term storag compar and save',
#  'Up To off lobster tail compar and save',
#  'Up To off lincoln Ls navig compar and save',
#  'Up To off Lg headset bluetooth compar and save',
#  'Up To off letter from santa compar and save',
#  'Up To off lens for nikon compar and save',
#  'Up To off lamp oil compar and save',
#  'Up To off oshkosh cloth compar and save',
#  'Up To off orchid show compar and save',
#  'Up To off optic tree compar and save',
#  'Up To off old maui compar and save',
#  'Up To off ohio arrowhead compar and save',
#  'Up To off ocean sunset compar and save',
#  'save chop suey item stock item quick ship',
#  'save time clock item stock item quick ship',
#  'Up To off full sheet compar and save',
#  'Up To off frontlin compar and save',
#  'Up To off ford rebuild compar and save',
#  'Up To off firewood storag compar and save',
#  'Up To off film polaroid compar and save',
#  'Up To off fender edit compar and save',
#  'Up To off F wd compar and save',
#  'Up To off grand jeep cheroke compar and save',
#  'Up To off golf ball marker compar and save',
#  'Up To off Hp printer compar and save',
#  'Up To off hot wheel pack compar and save',
#  'Up To off honeywel com compar and save',
#  'Up To off holiday puzzl compar and save',
#  'Up To off heritag massag compar and save',
#  'Up To off heirloom seed compar and save',
#  'Up To off harley dealership compar and save',
#  'save On harbor freight coupon compar and save',
#  'Up To off habitat human compar and save',
#  'Up To off notari public sign compar and save',
#  'Up To off new stuff compar and save',
#  'Up To off new envoy compar and save',
#  'Up To off navig compar and save',
#  'Up To off naturallyspeak compar and save',
#  'Up To off red spa compar and save',
#  'save On real estat In virginia compar and save',
#  'Up To off rack tire compar and save',
#  'Up To off militari bag compar and save',
#  'Up To off michel obama compar and save',
#  'Up To off miata hardtop compar and save',
#  'Up To off medic center compar and save',
#  'Up To off meat slicer stainless compar and save',
#  'Up To off black number compar and save',
#  'Up To off black friday compar and save',
#  'Up To off black friday compar and save',
#  'Up To off black friday compar and save',
#  'Up To off billiard store compar and save',
#  'Up To off big tex trailer compar and save',
#  'Up To off big lot compar and save',
#  'Up To off betsi mccall doll compar and save',
#  'Up To off best buy store compar and save',
#  'Up To off bersa thunder compar and save',
#  'Up To off beard dragon compar and save',
#  'Up To off bead cap compar and save',
#  'Up To off babi R Us compar and save',
#  'Up To off magnet lift compar and save',
#  'Up To off magic mart compar and save',
#  'Up To off mac makeup compar and save',
#  'Up To off manufactur usa compar and save',
#  'Up To off manhattan watch compar and save',
#  'Up To off makeup doll compar and save',
#  'Up To off cedar log compar and save',
#  'Up To off carver M compar and save',
#  'Up To off cartridg Hp compar and save',
#  'Up To off can juic compar and save',
#  'Up To off candi crane compar and save',
#  'Up To off camera pro compar and save',
#  'Up To off calvin bag compar and save',
#  'Up To off calendar month compar and save',
#  'Up To off dlo cabl compar and save',
#  'Up To off disney outlet store compar and save',
#  'Up To off disney dvd compar and save',
#  'Up To off dishnetwork compar and save',
#  'Up To off diod rectifi compar and save',
#  'Up To off plant water compar and save',
#  'Up To off plant moss compar and save',
#  'Up To off smart auto compar and save',
#  'Up To off diamond core compar and save',
#  'Up To off size compar and save',
#  'save On babi parti decor compar and save',
#  'Up To off decor tree compar and save',
#  'Up To off silver wire compar and save',
#  'Up To off silver flake compar and save',
#  'Up To off sidewalk paint compar and save',
#  'Up To off shoe pink compar and save',
#  'Up To off sheav align compar and save',
#  'Up To off parad Of light compar and save',
#  'Up To off paper wrap compar and save',
#  'Up To off paper christma compar and save',
#  'Up To off schwinn hybrid compar and save',
#  'Up To off scaffold compar and save',
#  'Up To off pajama set compar and save',
#  'Up To off tvr compar and save',
#  'Up To off sa shoe onlin compar and save',
#  'Up To off Tv itali compar and save',
#  'Up To off n part compar and save',
#  'Up To off santa letter from compar and save',
#  'Up To off santa clau face compar and save',
#  'Up To off sandal with compar and save',
#  'save On true love elizabeth arden compar and save',
#  'Up To off x camera compar and save',
#  'Up To off tree contain compar and save',
#  'Up To off transistor compar and save',
#  'Up To off trailer compar and save',
#  'Up To off tmobil minut compar and save',
#  'Up To off nissan sentra compar and save',
#  'Up To off silver proof compar and save',
#  'Up To off proof set compar and save',
#  'Up To off chrono trigger buy compar and save',
#  'save On christoph radko santa compar and save',
#  'Up To off thrift store compar and save',
#  'Up To off bread tin compar and save',
#  'Up To off thong swimsuit compar and save',
#  'Up To off thoma the engin compar and save',
#  'Up To off ford compar and save',
#  'Up To off brass furnitur pull compar and save',
#  'Up To off the porcelain doll compar and save',
#  'Up To off chicken clay pot compar and save',
#  'Up To off the ledg compar and save',
#  'Up To off the accordion compar and save',
#  'Up To off dvd compar and save',
#  'Up To off territori ahead compar and save',
#  'Up To off tent sale compar and save',
#  'Up To off tent On sale compar and save',
#  'save On cheaper ga electr compar and save',
#  'Up To off boden cloth compar and save',
#  'Up To off bmw motorcycl compar and save',
#  'Up To off charmglow grill part compar and save',
#  'Up To off chair set compar and save',
#  'Up To off cetyl M compar and save',
#  'Up To off cyber shop compar and save',
#  'Up To off T mobil phone compar and save',
#  'Up To off T mobil minut compar and save',
#  'Up To off celtic ticket compar and save',
#  'Up To off cue ball compar and save',
#  'Up To off duofast compar and save',
#  'Up To off cross stitch how To compar and save',
#  'Up To off pump impel compar and save',
#  'Up To off driven life compar and save',
#  'Up To off crayola product compar and save',
#  'Up To off cragar wheel compar and save',
#  'Up To off sutorbilt blower compar and save',
#  'Up To off dream essenti compar and save',
#  'Up To off surlat compar and save',
#  'Up To off motorcycl vintag compar and save',
#  'Up To off motorcycl sale compar and save',
#  'Up To off moss seed compar and save',
#  'Up To off moss plant compar and save',
#  'Up To off print label compar and save',
#  'Up To off dollhous light compar and save',
#  'Up To off dog To buy compar and save',
#  'save On stroller weather shield compar and save',
#  'Up To off dog buy compar and save',
#  'Up To off dog barrier compar and save',
#  'Up To off cooper ridg compar and save',
#  'save On strawberri chocol compar and save',
#  'Up To off moistur wick compar and save',
#  'Up To off stitch cross compar and save',
#  'Up To off ml home for sale compar and save',
#  'Up To off compressor compar and save',
#  'Up To off minut T mobil compar and save',
#  'Up To off star light compar and save',
#  'Up To off color book free compar and save',
#  'save On pontiac firebird formula compar and save',
#  'Up To off color dark brown compar and save',
#  'Up To off polo bag compar and save',
#  'Up To off coldwat creek compar and save',
#  'Up To off polaroid one step compar and save',
#  'Up To off polaroid one compar and save',
#  'Up To off polarfleec compar and save',
#  'Up To off sport good com compar and save',
#  'Up To off plastic toothpick compar and save',
#  'Up To off socket compar and save',
#  'Up To off sock loom compar and save',
#  'Up To off snow plow truck compar and save',
#  'Up To off snow plow for truck compar and save',
#  'Up To off snakeroot compar and save',
#  'PC optim pro free window download',
#  'fli airberlin berlin book airberlincom save',
#  'fli airberlin berlin book airberlincom save',
#  'top cell more about metro pc',
#  'free instal full version window download',
#  'download solitair card game free theappcentercom',
#  'classic solitair game window download free full version',
#  'easili import file save ani other format libreoffic',
#  'creat edit rich text document window full version instal',
#  'download libreoffic free theappcentercom visit now',
#  'full version window download get It free today instant instal',
#  'download shop win browser earn free sweepstak entri visit Us',
#  'Up To off duo fast compar and save',
#  'Up To off drleonard compar and save',
#  'Up To off vera bradley compar and save',
#  'Up To off joann fabric coupon compar and save',
#  'Up To off factori jewelri compar and save',
#  'amaz hostel altern book A privat apart from n now',
#  'entir home hostel price upgrad holiday today',
#  'fast loan reason rate militari personnel',
#  'search for air condition low price On air condition heat pump',
#  'inform idea save save On the shark vacuum',
#  'search for warm drawer low price On food warmer',
#  'get bargain deal On shop At lord and taylor At lowpriceshopp',
#  'get the biggest bang for your buck deal On purpos driven life review',
#  'get bargain deal On planet Of the ape dvd At lowpriceshopp',
#  'Of choic for batteri save On odyssey batteri',
#  'save more shop more off send A teddi bear',
#  'inform idea save save On nikon camera lens',
#  'inform idea save save On electr suppli compani',
#  'find parti suppli low price On cheap yoyo',
#  'inform idea save save On that all folk',
#  'search cell phone gear low price On leather cell phone case',
#  'get bargain deal On DJ equip packag At lowpriceshopp',
#  'inform idea save save On fender guitar',
#  'inform idea save save On gp shop',
#  'inform idea save save On navig system',
#  'search Of electron deal On buy video cam',
#  'search Of electron deal On aiwa home theater',
#  'compar projector low price On sanyo plcxf',
#  'find speaker headphon low price On aiwa stereo home',
#  'get the biggest bang for your buck deal On siriu radio satellit',
#  'buy newus travel trailer your area great price visit Us',
#  'you could get new car refund cost honor aba',
#  'join Us for free save wizard citi start your magic adventur now',
#  'join Us for free save wizard citi start your magic adventur now',
#  'chose wizard start magic adventur now',
#  'join Us for free save wizard citi start your magic adventur now',
#  'join Us for free save wizard citi start your magic adventur now',
#  'see latest browser game chart play game free',
#  'see latest browser game chart play game free',
#  'play free onlin game over onlin game site',
#  'play free onlin game over onlin game site',
#  'play free onlin mmo mmorpg find favorit onlin game',
#  'see latest onlin game chart play onlin game free',
#  'see latest multiplay game play game free',
#  'play free fun game come site start',
#  'play free fun mmo mmorpg find favorit fun game',
#  'play free fun game come site start',
#  'play free free mmo mmorpg find favorit free game',
#  'play free game onlin over free game site',
#  'play free free mmo mmorpg find favorit free game',
#  'see latest free game chart play game free',
#  'play free game onlin the latest free game site',
#  'play free game onlin the latest free game site',
#  'play free free mmo mmorpg find favorit free game',
#  'play free game onlin over free game site',
#  'the limit imagin build world free now',
#  'roblox design play amaz D game for kid teen adult',
#  'roblox design play amaz D game for kid teen adult',
#  'the limit imagin build world free now',
#  'free ship qualifi order buy intellig design Vs evolut amazon',
#  'low price new use rap hiphop music',
#  'free ship qualifi order buy chest workout amazon',
#  'million titl new use free ship qualifi order',
#  'million titl new use free ship qualifi order',
#  'million titl new use free ship qualifi order',
#  'save tool more Up free ship qualifi order',
#  'low price million book free ship qualifi order',
#  'free day ship w amazon prime low price million book',
#  'onestop shop movi TV free ship qualifi order',
#  'free day ship w amazon prime low price million book',
#  'low price A charger free ship qualifi order',
#  'onestop shop movi TV free ship qualifi order',
#  'huge select low price stay healthi support your lifestyl',
#  'onestop shop movi TV free ship qualifi order',
#  'free day ship w amazon prime low price million book',
#  'second applic easi fast approv drive today',
#  'second applic easi fast approv drive today',
#  'second applic easi fast approv drive today',
#  'ti season save off fuji road bike',
#  'shop lord and taylor petit off top style brand',
#  'ti season save off fork tube',
#  'shop heat pump air condition off top style brand',
#  'discov bush At the site devot To shop',
#  'discov hand paint wine glass beach At the site devot To shop',
#  'discov honda suspens kit site devot shop',
#  'ti season save off toy r us toy',
#  'ti season save off obama american flag',
#  'shop lake girl hoodi off top style brand',
#  'shop cannondal jekyl off top style brand',
#  'ti season save off yellow jacket bee sale',
#  'ti season save off schwinn hybrid',
#  'ti season save off spring creativ fabric',
#  'ti season save off kohl coverlet',
#  'discov kelsey cotton shop design brand off',
#  'ti season save off tuff shed kit',
#  'discov auto draft induc site devot shop',
#  'ti season save off auto draft induc',
#  'shop surfac tablet commerci off top style brand',
#  'shop nate berku collect top bathroom style low price',
#  'discov plastic toothpick angl At the site devot To shop',
#  'shop crackl glaze pot off top style brand',
#  'ti season save off blue yellow pillow',
#  'ti season save off homemad wooden christma ornament',
#  'shop blackout curtain off top style brand',
#  'shop shelv ledg off top style brand',
#  'ti season save off the hottest product',
#  'discov abit motherboard off top style brand',
#  'discov router review off top style brand',
#  'discov Mp player with Fm radio off top style brand',
#  'discov alcohol fill chocol off top style brand',
#  'discov kraft spaghetti dinner At the site devot To shop',
#  'deal speedo thong swimsuit top swimwear style low price',
#  'deal olymp lift shoe top shoe style low price',
#  'deal www famou shoe com top shoe style low price',
#  'deal olymp weightlift shoe top shoe style low price',
#  'shop Tj maxx cloth for women Be So stylish find shirt top',
#  'deal shoe guess boot top shoe style low price',
#  'ti season save off way wear silk scarf',
#  'ti season save off rainforest rain jacket',
#  'ti season save off ruger hat',
#  'find adida ladi adistar top brand sale free ship',
#  'discov convers cheap onlin off top style brand',
#  'shop peep toe women booti top shoe style low price',
#  'shop beret pattern top hat style low price',
#  'deal beret pattern top hat style low price',
#  'discov barack obama flag site devot shop',
#  'ti season save off cutter buck cotton trouser',
#  'shop way To wear A neck scarf top scarf style low price',
#  'shop charger straw hat top hat style low price',
#  'discov for hair vitamin site devot shop',
#  'ti season save off gp car navig',
#  'discov echostar dish site devot shop',
#  'ti season save off hisens hd tv',
#  'ti season save off rca cabl video',
#  'discov pioneer elit Tv plasma off top style brand',
#  'ti season save off navig system',
#  'ti season save off siriu portabl radio',
#  'shop magic mart com off top style brand',
#  'ti season save off dinosaur lego',
#  'shop perfect game off top style brand',
#  'shop hotwheel collector off top style brand',
#  'ti season save off remot control race car',
#  'shop lalaloopsi doll pillow off top style brand',
#  'shop disney ship off top style brand',
#  'deal yoyo duncan shop top brand off',
#  'furnish hous studio citi shortterm leas monthli stay',
#  'temporari apart san diego shortterm leas monthli stay',
#  'low price best seller new releas classic',
#  'compar today rate free act now get quot now submit your info',
#  'get tip advic howto for all your home project',
#  'get tip idea for all your kitchen need At houselog',
#  'get tip idea for all your home need At houselog',
#  'let houselog show you tip for home repair improv',
#  'let houselog show you tip for home repair improv',
#  'shop discoveri made simpl explor fitch fuel catalyst',
#  'explor oven save wolf ga stove',
#  'deal On cheap yoyo great action and fun for your kid',
#  'discov season top deal off appliqu wood',
#  'make parti memor save pennant banner',
#  'tissu paper bulk At cheap price perfect for your outdoor job',
#  'air duct save On gener build materi',
#  'explor fuel filter diesel get auto part for less',
#  'auto part merchant deal fuel filter diesel',
#  'shop discoveri made simpl explor babi bjorn discount',
#  'shop discoveri made simpl explor excedrin headach tension',
#  'explor miscellan item deal zanfel poison ivi',
#  'explor miscellan item deal topic solut',
#  'play run have fun save kid playground slide',
#  'electr wire To choos from perfect for home and offic use',
#  'home improv choic deal regul volt',
#  'lawn garden choic deal masterbuilt grill cover',
#  'michael kor skirt shop for skirt At smart price',
#  'great deal On w power suppli never run short Of backup again',
#  'art craft suppli save canva acryl paint',
#  'discov season top deal off drawer pull',
#  'explor cutleri choic deal glass cut board',
#  'revel festiv W option shop simpl homemad christma ornament now',
#  'explor sandal slip columbia sandal women',
#  'sport outdoor option find deal On x soccer goal',
#  'x soccer goal At cheap price easi To use and portabl goal',
#  'get motherboard bundl cpu At low price make your system more profici',
#  'discov season top deal off storag jar glass',
#  'dresser fantast select enhanc the look Of your home',
#  'low price choic save freestyl glucos meter',
#  'explor clock choic discov clock radio cd player',
#  'home improv choic save bathroom tile',
#  'discov season top deal off babi bingo shower',
#  'shop discoveri made simpl explor johnni walker blue',
#  'explor bugera save big On instrument amplifi',
#  'shop discoveri made simpl explor christma decor tabl',
#  'shop discoveri made simpl explor wrestl sweatshirt',
#  'ralph lauren blue save big On women pant',
#  'discov season top deal off design swimwear',
#  'hardwar home offic save buy pro',
#  'discov season top deal off buy pro',
#  'handbag purs tote deal sheepdog shelti shetland',
#  'discov season top deal off fli tie vise',
#  'explor home decor choic deal religi figur',
#  'decor new figurin deal religi figur',
#  'shop discoveri made simpl explor bike brake pad',
#  'select from over ipod dock cd player great deal On clock radio',
#  'pamper your dog deal outdoor pet kennel',
#  'brows cobra golf review get great discount On golf club',
#  'hot wheel pack At low price stylish durabl bag for you',
#  'explor televis deal televis mitsubishi',
#  'save On cocktail parti attir turn head with the latest design',
#  'explor parti suppli save tissu ball',
#  'discov season top deal off christma tree decor',
#  'discov season top deal off silver buckl ring',
#  'explor car electron save alarm crimestopp',
#  'explor sauder choic save sauder stand tv',
#  'shop discoveri made simpl explor sauder stand tv',
#  'discov season top deal off sauder stand tv',
#  'shop discoveri made simpl explor ngk iridium spark plug',
#  'betsi mccall doll To choos from great deal On doll for kid',
#  'save On icarli merchandis new eleg To your home decor',
#  'make your hair happi discov goldwel color',
#  'shirt accessori deal I love T shirt',
#  'start home improv project save sulfur spray',
#  'discov season top deal off sulfur spray',
#  'discov season top deal off sale road bike',
#  'part bin storag In stock grab our qualiti kid room item',
#  'explor yanke candl save big On shop yanke candl',
#  'hit slope ski board choos snow ski kid',
#  'discov season top deal off steel clamp',
#  'shop discoveri made simpl explor glucophas xr',
#  'explor rim cheap fantast save On tire rim',
#  'discov season top deal off hair color dark brown',
#  'blu ray dvd combo At cheap price high perform drive for you',
#  'shop discoveri made simpl explor printer canva',
#  'nissan titan save big On auto part',
#  'power tool you choos incred deal On pocket hole guid',
#  'shop loi vuitton handbag stylish bag for savvi peopl',
#  'discov season top deal off kayak sail',
#  'explor bed choic discov berku',
#  'start home improv project deal head bolt',
#  'discov season top deal off kid christma ornament',
#  'discov season top deal off hammer bowl bag',
#  'shoe fit your style save kid dress shoe',
#  'find hottest toy game save jato part',
#  'robot radio control toy save jato part',
#  'shop discoveri made simpl explor women cocktail dress',
#  'paper towel dispens At low price get all your clean suppli',
#  'find right tool job discov cooki jar',
#  'discov season top deal off car satellit radio',
#  'calvin klein bag you choos never Go wrong with A classic bag',
#  'deal On zx car put excel In your vehicl',
#  'deal On super bounc ball great action and fun for your kid',
#  'discov season top deal off toothpick plastic',
#  'discov season top deal off philip audio system',
#  'find ge front load wash machin deal reliabl and highli rate By user',
#  'discov season top deal off jake shirt',
#  'black walnut cologn On sale huge bargain On cologn To avail',
#  'explor big deal On automobil gp review stay connect with new technolog',
#  'explor heavi duti steel clamp great bargain On hand tool',
#  'new titleist golf ball incred deal On golf equip',
#  'shop discoveri made simpl explor silver proof',
#  'gourmet treat store save rum cruzan',
#  'build your collect deal silver proof set',
#  'hot Mp player cool price choos ipod classic',
#  'discov season top deal off pioneer plasma elit tv',
#  'discov season top deal off lobster net',
#  'hub switch for sale bring home the latest technolog',
#  'deal On hand tool save On lift magnet',
#  'discov season top deal off buy ga furnac',
#  'shop discoveri made simpl explor gerbera',
#  'discov season top deal off gerbera',
#  'shop discoveri made simpl explor mail sorter',
#  'discov season top deal off charger apparel',
#  'deal On canondal bike cloth To complement your style',
#  'pencil fantast select noth but the best for your kid',
#  'shop discoveri made simpl explor buy wii',
#  'choic low price find mustang suit',
#  'sterl silver bullet At cheap price ear that make you shine out',
#  'explor top rate rang huge rang mighti discount',
#  'factori jewelri livonia incred save On top brand',
#  'hand held solitair To explor amaz deal On toy game',
#  'explor food gourmet gift save champagn clicquot',
#  'sport bag An activ life discov militari duffl bag',
#  'spreader fertil At low price give your crop all nutrient It need',
#  'discov season top deal off track jacket men',
#  'discov season top deal off buy tmobil minut',
#  'att cell phone plan To explor find mega deal On cell phone',
#  'shop discoveri made simpl explor sink odor',
#  'shop discoveri made simpl explor chrysanthemum purpl',
#  'stylish bowl bag for you compar price On bowl bag',
#  'explor zooper babi stroller get great discount On stroller',
#  'shop discoveri made simpl explor mobil shc',
#  'build your dream home theater choos portabl soni dvd player',
#  'swim pool jacuzzi item get emerson motor item',
#  'discov season top deal off emerson motor',
#  'shop discoveri made simpl explor ps',
#  'discov season top deal off standbi gener',
#  'explor necklac save jewelri factori livonia',
#  'explor hardwar choic save canon scanner printer',
#  'boat On high sea lake save electr winch',
#  'discov season top deal off voodoo doll',
#  'shop discoveri made simpl explor yard machin part',
#  'shop discoveri made simpl explor fring drape',
#  'hammer bowl bag At afford price choos adorn great design',
#  'shop discoveri made simpl explor heat pump air condition',
#  'great deal On heat pump air condition beat the heat thi summer',
#  'start home improv project deal hardwood floor nailer',
#  'make parti memor save cheap scoobi doo parti suppli',
#  'home improv choic save american standard toilet seat',
#  'shop aprilair air filter bargain price On dehumidifi',
#  'explor parti tent sale find huge discount On tent',
#  'shop discoveri made simpl explor convers athlet shoe',
#  'explor auto repair tool deal auto batteri',
#  'find cloth accessori save scarf wear',
#  'big deal On cheap comput laptop desk sleek stylish laptop furnitur',
#  'shop discoveri made simpl explor boutiqu women',
#  'shop discoveri made simpl explor blower',
#  'wall drawer shelf On huge sale easi and durabl storag option',
#  'discov season top deal off shelv ledg',
#  'deal On kasper women suit turn head with the latest design',
#  'discov season top deal off treadmil sale',
#  'discov season top deal off chicago bear memorabilia',
#  'shop discoveri made simpl explor appl tv',
#  'handbag purs tote deal On sale design handbag',
#  'shop discoveri made simpl explor seattl best coffe',
#  'shop discoveri made simpl explor basketbal shose',
#  'shop discoveri made simpl explor emeril essenc season',
#  'shop discoveri made simpl explor glass magnifi',
#  'shop discoveri made simpl explor lip seneg',
#  'brows jcb backho loader save big On outdoor toy and game',
#  'deal On girl holiday pajama cozi nightwear for comfi sleep',
#  'kitchen suppli utensil huge deal On dollarday',
#  'discov season top deal off dollarday',
#  'discov season top deal off toastmast toaster oven',
#  'shop discoveri made simpl explor fc barcelona apparel',
#  'explor gift product save tone season',
#  'find food gourmet gift save rice crispi cereal treat',
#  'shop discoveri made simpl explor fleetwood doubl wide home',
#  'shop discoveri made simpl explor furnitur arhau',
#  'bath accessori choic deal On cassetta',
#  'eleg necklac your style save swarovski crystal cross',
#  'discov season top deal off swarovski crystal cross',
#  'beautifi your bathroom save bath mat kid',
#  'shop discoveri made simpl explor cheap window',
#  'shop discoveri made simpl explor collect ltd',
#  'discov season top deal off westward tool box',
#  'ford carburetor get automot part for less',
#  'hardwar home offic save mac soho',
#  'find mac soho At afford price print In A blink Of An eye',
#  'mac soho deal for you incred save On top brand',
#  'shop discoveri made simpl explor mac soho',
#  'discov season top deal off mac soho',
#  'discov season top deal off garden knee pad',
#  'deal On grand prix chrome right part for the right vehicl',
#  'decor your dream nurseri explor soccer bed set',
#  'shop discoveri made simpl explor cross stitch hoffman',
#  'brows sound blaster audio card compar price On sound card',
#  'shop black white kid dress fantast select look stylish with fabul dress',
#  'shop network cabl wire choos for enhanc connect',
#  'choic low price discov bead cap',
#  'mega deal On ati graphic driver A boost To visual comput',
#  'explor storag choic save storag unit cost',
#  'inch drawer pull option for you get great deal today',
#  'shop discoveri made simpl explor blue dog hound',
#  'discov season top deal off micro magnet',
#  'shop discoveri made simpl explor domain leopard',
#  'discov season top deal off men pajama big tall',
#  'bandsaw saw mill At afford price home tool for all your need',
#  'explor pioneer car kit inno get deal On radio accessori',
#  'discov season top deal off stetson hat western',
#  'shop discoveri made simpl explor sidewalk paint',
#  'teach scaffold To pick save On languag book',
#  'mm canon At veri low price take perfect pictur easili',
#  'discov season top deal off e fish rod',
#  'discov season top deal off step bar truck',
#  'discov season top deal off upsid cupcak pan',
#  'explor pioneer satellit radio get deal On radio accessori',
#  'bell whistl cell save phone verizon',
#  'shop discoveri made simpl explor crimestopp rs',
#  'tester electr for sale featur that exce expect',
#  'discov season top deal off luggag spinner sale',
#  'discov season top deal off lobster net',
#  'bedroom set In store mingblow deal On bedroom set',
#  'home improv choic deal cost electr low',
#  'cookwar for you shop clay cook pot',
#  'auto part merchant deal merced cd navig',
#  'explor hat save navi ship cap',
#  'kitchen suppli utensil huge deal On humpback whale calf',
#  'shop discoveri made simpl explor kn air cleaner',
#  'splash into save deal thong swimsuit clearanc',
#  'farmer almanac On offer smart deal On inform book',
#  'shop discoveri made simpl explor cato cloth women',
#  'build your collect deal silver proof set',
#  'shop discoveri made simpl explor zoomtext keyboard',
#  'discov season top deal off zoomtext keyboard',
#  'explor skin product choic save face santa clau',
#  'explor televis save cobi led tv',
#  'explor hardwar choic save allinon hp printer',
#  'step out In style save jrene sandal',
#  'hardwar home offic save canon pixma ipv',
#  'discov new home decor deal incens stick',
#  'step out In style save sandal',
#  'hex nylon socket option for you get great deal today',
#  'bargain price smart deal explor grommet blackout curtain',
#  'explor dress save navi lace adrianna papel dress',
#  'explor perfum cologn deal On elizabeth arden true love gift set',
#  'the scent you explor perfum cologn scent',
#  'explor babi stroller save babi doubl stroller',
#  'home improv choic save black modern brass drawer pull',
#  'ti season save off babi disney stroller',
#  'ti season save off ethan home iron king bed',
#  'start home improv project deal drywal anchor',
#  'brown laurey brass drawer pull At low price extra secur for your door',
#  'save big On nois cancel bose headphon share your music out loud',
#  'save On cobi led tv find TV At A price that suit you',
#  'shop discoveri made simpl explor edg handcraft mirror',
#  'explor televis save cobi led tv',
#  'bargain price smart deal explor citi seat',
#  'bargain price smart deal explor game comput',
#  'discov new home decor deal yanke candl shop',
#  'explor televis save black friday sale tv',
#  'danc wear solut for you great deal On halloween costum',
#  'deka batteri At low price the perfect backup for your devic',
#  'shop discoveri made simpl explor kellogg rice krispi treat cereal',
#  'explor shoe explor huge rang Of footwear',
#  'explor barbi doll makeup save great deal On doll and toy',
#  'discov season top deal off iron maiden shirt',
#  'discov season top deal off doll sell',
#  'discov season top deal off emerson electr motor',
#  'explor tabl choic save Tv tabl stand',
#  'handbag tote At low price never Go wrong with A classic bag',
#  'shop discoveri made simpl explor verizon phone sale',
#  'discov season top deal off charmglow replac part',
#  'shop discoveri made simpl explor record dvd vh',
#  'comput accessori for you save huge On comput monitor',
#  'great deal On laptop replac screen give you A crystal clear pictur',
#  'find tent At afford price A solid outdoor shelter for you',
#  'shop discoveri made simpl explor hors cross stitch',
#  'televis speaker for sale shop stereo speaker headphon',
#  'lawn garden choic save discharg hose',
#  'explor woodmiz saw mill find huge select Of power saw',
#  'shop discoveri made simpl explor fruit high vitamin k',
#  'deal On panason plasma tv chang the way you see the world',
#  'comfi thoma train chair mega sale On kid furnitur',
#  'choic low price find skull bandana',
#  'back window decal To grab great deal On auto accessori',
#  'see clearli find vision product discov dior eyeglass',
#  'shop discoveri made simpl explor argan oil benefit',
#  'discov season top deal off acryl paint canva',
#  'explor craft suppli deal fabric',
#  'automot accessori save merced navig system',
#  'shop discoveri made simpl explor slide door',
#  'the scent you explor lauren hot perfum',
#  'explor perfum cologn deal On perfum cologn scent',
#  'shop discoveri made simpl save On elizabeth arden true love gift set',
#  'discov season top deal off chassi ford',
#  'shop discoveri made simpl explor babi bjorn bouncer',
#  'explor handbag for you chanel authent handbag for less',
#  'loui vuitton handbag bundl Up In style W handbag',
#  'handbag purs tote deal design handbag sale',
#  'brown pant At afford price the comfort eas you right away',
#  'get deal On high top air forc find your fit here',
#  'deal On surgic scrub cap design that everyon will envi',
#  'explor hat save u navi hat',
#  'discov season top deal off plastic luggag cover',
#  'emilio pucci sale never Go out Of style',
#  'bead cap for sale turn head with the latest design',
#  'discov season top deal off bonworth cloth',
#  'save On essenc cloth dress for classi upscal women',
#  'discov season top deal off driver ati',
#  'hot brand cool price save cato women wear',
#  'shop discoveri made simpl explor tmobil cell',
#  'discov season top deal off eucalyptu seed',
#  'deal On mobil refil minut accessori To beautifi your phone',
#  'find mobil refil minut incred save On top brand',
#  'discov season top deal off cost dentur',
#  'shop discoveri made simpl explor carmol',
#  'art craft suppli save oil paint reproduct',
#  'explor craft suppli deal cookbook binder',
#  'emerson electr motor for sale featur that exce expect',
#  'discov season top deal off flat panel vizio',
#  'rv storag cost At low price keep your garden neat tidi',
#  'everyth your lawn garden save starter seed tray',
#  'discov season top deal off wing chair white',
#  'discov season top deal off atlant cd holder',
#  'save On palm leaf wallpap new eleg To your home decor',
#  'home improv choic save portabl saw mill',
#  'shop discoveri made simpl explor ati graphic driver',
#  'ati graphic driver for sale bargain price On graphic card',
#  'shop discoveri made simpl explor adida cloth',
#  'discov season top deal off fastsel product',
#  'home improv choic deal mobil shc',
#  'great bargain On sur la tabl add elegantli W stylish tabl linen',
#  'explor home decor choic discov sur La tabl',
#  'discov new dine decor save sur La tabl',
#  'shop discoveri made simpl explor car comput',
#  'discov season top deal off emerson fan part',
#  'furnitur At afford price creat A better live space',
#  'discov season top deal off lawn mower replac part',
#  'shop discoveri made simpl explor bath tile ceram',
#  'big deal On nikon mm experi the latest technolog',
#  'shop discoveri made simpl explor psw',
#  'shop discoveri made simpl explor silver flake',
#  'shop discoveri made simpl explor storm jersey',
#  'shop discoveri made simpl explor bedroom stuff teen',
#  'shop discoveri made simpl explor hous air filter',
#  'shop discoveri made simpl explor wall hang lamp',
#  'shop discoveri made simpl explor classroom jeopardi buzzer',
#  'shop discoveri made simpl explor spring hill bulb',
#  'grand prix door To grab great deal On auto accessori',
#  'discov season top deal off ford road bumper',
#  'shop discoveri made simpl explor tyre',
#  'explor automot tire save On tyre',
#  'grab tyre explor amaz deal now',
#  'shop discoveri made simpl explor pacifi',
#  'semi circl chair At low price noth but the best for your kid',
#  'discov season top deal off semi circl chair',
#  'explor bed choic save On super mario brother comfort',
#  'explor men sport shoe find deal On adistar adida',
#  'shop cp basketbal shoe play the game In comfi shoe',
#  'discov season top deal off hunter rain boot',
#  'shop nike air forc one high top shoe meant for great comfort',
#  'shop nike airforc one shoe meant for great comfort',
#  'shop discoveri made simpl explor thong swimsuit',
#  'sale On air max nike shoe women footwear To complement your style',
#  'connect your compon shop rca tv consol',
#  'cell phone accessori deal On lg optimu',
#  'newest verizon cell phone To shop get cell phone essenti',
#  'navig By star Is overr choos gp cyber monday deal',
#  'shop discoveri made simpl explor flower plant',
#  'refresh your skin discov secret flawless renew',
#  'shop discoveri made simpl explor amoryn review',
#  'low price choic save On melatonin sleep tablet',
#  'explor skin product choic save On bed bath',
#  'discov season top deal off johnson johnson pad',
#  'shop discoveri made simpl explor furnitur pull knob',
#  'deal On garag door hardwar revamp your garag door now',
#  'wing chair white antiqu design for live room',
#  'discov season top deal off industri consol tabl',
#  'livin room furnitur deal modern furnitur la deal',
#  'style that fit your life price explor vintag consol tv',
#  'shop discoveri made simpl explor variou product',
#  'adida gear To choos from save more spend less shop here',
#  'save On chrysanthemum varieti get readi for An excit game',
#  'discov season top deal off hand well water pump',
#  'bike At afford price ride On for An adventur journey',
#  'discov season top deal off moab mountain bike',
#  'tri bike At afford price ride On for An adventur journey',
#  'belk bedspread At afford price find rich royal color comfort',
#  'great deal On beatl shoe convers shoe for all day comfort eas',
#  'discov season top deal off fuji road bike sale',
#  'discov season top deal off la modern furnitur',
#  'lord taylor furnitur shop now save big',
#  'discov season top deal off bed nightstand',
#  'shop discoveri made simpl explor bedroom queen set',
#  'shop discoveri made simpl explor send teddi bear',
#  'shop discoveri made simpl explor liteon ps',
#  'shop discoveri made simpl explor decor christma tree',
#  'discov season top deal off iron maiden shirt',
#  'great deal On home tabl furnish your home with stylish tabl',
#  'viewson vfdw for sale bring home the latest technolog',
#  'shop discoveri made simpl explor emerald princess',
#  'discov season top deal off guitar dobro',
#  'shop discoveri made simpl explor life poet',
#  'shop discoveri made simpl explor mini address book',
#  'score soccer equip choos barcelona Fc youth',
#  'enjoy the great outdoor save On crosman pellet bb gun',
#  'shop discoveri made simpl explor item sold tv',
#  'shop discoveri made simpl explor larg slip slide',
#  'boot santa On sale find the right halloween costum',
#  'boot santa dress Up In style thi halloween',
#  'style Is In the bag save calvin klein bag',
#  'deal On handbag and tote shop save On calvin klein bag',
#  'blue cotton carol hochman pajama set hot deal On sleepwear',
#  'discov season top deal off cutter buck wallet',
#  'handbag tote At cheap price handbag To match your style',
#  'shop discoveri made simpl explor handbag tote',
#  'discov season top deal off jessica simpson tote handbag',
#  'luggag choic discov nautica bag',
#  'explor xxl floral print woven pajama set top deal On sleepwear pajama',
#  'carri book boot you choos save ralph lauren backpack',
#  'calvin klein bag you choos never Go wrong with A classic bag',
#  'ti season save off calvin klein duffel bag',
#  'awesom handbagstot huge deal On your favorit brand',
#  'explor choic huge save On nautica luggag set',
#  'glass ball canning jar At afford price take care Of home can need',
#  'discov season top deal off notebook hp probook',
#  'shop discoveri made simpl explor home secur camera',
#  'get the biggest bang for your buck deal On babi stroller',
#  'save more shop more off babi disney stroller',
#  'save more shop more off babi cradl',
#  'save more shop more off johnson johnson babi wipe',
#  'ti season save off new nike air max',
#  'ti season save off seen tv product',
#  'comfi Or sexi you choos deal On seen tv product',
#  'ti season save off women bra',
#  'air To breath clean free discov split air condition heat pump',
#  'ladi nightshirt for you perfect for your cozi sleep',
#  'explor gift product save On blue agav sweeten',
#  'explor hair product choic deal seen tv hair product',
#  'explor bed choic deal sew fleec blanket',
#  'china hutch buffet deal reliabl highli rate By user',
#  'kitchen island choic save kitchen island cart storag',
#  'shirt accessori deal On love shirt',
#  'everyth your lawn garden deal automat plant water',
#  'bargain price smart deal explor automat plant water',
#  'bargain price smart deal explor dr leonard bedspread',
#  'ti season save off happi birthday placemat',
#  'homestyl kitchen island shop offer On kitchenwar',
#  'pamper your dog save pet vehicl barrier',
#  'titleist golf incred deal On golf equip',
#  'bargain price smart deal explor titleist golf',
#  'fisher price ocean wonder for you great deal On doll',
#  'explor mermaid tail swim great deal On mermaid costum',
#  'adult halloween costum idea save huge On halloween costum',
#  'stay On track with new tire deal michelin tire review',
#  'explor automot tire deal review michelin tire',
#  'shop discoveri made simpl explor kid tabl chair set',
#  'tabl chair set kid At low price noth but the best for your kid',
#  'stetson western hat At low price turn head with the latest design',
#  'hot fashion cool momma save On women matern dress',
#  'discov season top deal off disney mickey stroller',
#  'discov season top deal off cutter buck polo',
#  'shop discoveri made simpl explor wolf oven stove',
#  'find cloth accessori save On sock smartwool',
#  'shop nike air forc high top shoe meant for great comfort',
#  'explor athlet shoe slip nike air forc high top',
#  'discov season top deal off glacier nation park',
#  'get women gown At low price get varieti Of style and size',
#  'shop discoveri made simpl explor cocktail dress',
#  'save On bass shoe for women big deal On gh bass loafer',
#  'gourmet treat store save shellback',
#  'discov season top deal off shellback',
#  'shop discoveri made simpl explor youngblood miner cosmet',
#  'feel beauti discov bobbi brown face palett',
#  'shop discoveri made simpl explor strivectin face',
#  'explor perfum cologn deal On ralph ralph lauren perfum',
#  'shop discoveri made simpl explor danc star clip',
#  'explor swimwear choic save On plu size swimsuit',
#  'start A home improv project deal On wire connector har',
#  'start A home improv project deal On indoor extens cord',
#  'discov season top deal off barcelona fc footbal club',
#  'franc flag On sale outdoor decor option for you',
#  'discov new outdoor decor deal franc flag',
#  'home improv choic save On hot water heater electr',
#  'home improv choic save On bosch ev',
#  'huge bargain On bosch sd rotari hammer drill A brand that deliv qualiti',
#  'discov season top deal off bosch sd rotari hammer drill',
#  'lawn garden choic save On bahia grass seed',
#  'shop discoveri made simpl explor thoma train ticket',
#  'great deal On simmon beautyrest king size feel comfort while sleep',
#  'save big On paddl board find all gear you need for boat',
#  'hit the court play like A pro save On basketbal drill youth',
#  'boat On high sea lake explor kayak',
#  'shop discoveri made simpl explor outboard engin',
#  'men flip flop To choos from collect that scream style',
#  'discov season top deal off bosch vsr hammer',
#  'hardwar home offic save viewson lcd monitor',
#  'huge bargain On bosch v hammer A brand that deliv qualiti',
#  'shop discoveri made simpl explor natur landmark sconc',
#  'discov season top deal off swarovski chandeli',
#  'ti season save off white snake print men shoe',
#  'get puma men footwear deal incred save On top brand',
#  'ti season save off viewson lcd monitor',
#  'floor choic deal On wood baseboard mold',
#  'sd At low price the hardest task look effortless',
#  'home improv choic deal sd',
#  'find right tool job save rotari dhpc hammer',
#  'find right tool job save rotari sd metal hammer',
#  'home improv choic deal steel bush tool',
#  'home improv choic save bosch rotari hammer bit',
#  'bargain price smart deal explor natur landmark sconc',
#  ...]

# %%
xglue['train'][0:5]
# Out:
# {'ad_description': ['Your New England Cruise Awaits! Holland America Line Official Site.',
#   'Explore Your World with Four Extraordinary Offers.',
#   'Cruise to Your Own Private Island In the Caribbean. Learn More Now.',
#   'Sign Up for Offers and Explore the Caribbean with Holland America Line',
#   'Official Site - Sign Up for Special New England Cruise Offers Today.'],
#  'ad_title': ['New England Cruises',
#   'Holland America Line®',
#   'Holland America Line®',
#   'Caribbean Cruises',
#   'Holland America Line®'],
#  'query': ['cruise portland maine',
#   'transportation to cruise port miami',
#   'transportation to cruise port miami',
#   'galveston cruise parking',
#   'cruise portland maine'],
#  'relevance_label': [1, 0, 1, 0, 1]}

# %%
vectorizerX = TfidfVectorizer(max_df=10, min_df=3)
vectorizerX.fit(cleaned_corpus)
doc_vector = vectorizerX.transform(cleaned_corpus)
print(vectorizerX.get_feature_names())

print(doc_vector.shape)
# Out:
# ['aa', 'aacom', 'aacsb', 'aadvantag', 'aaea', 'aaf', 'aagsk', 'aamco', 'aand', 'aap', 'aarporg', 'aask', 'aba', 'abacoa', 'abap', 'abat', 'abbb', 'abbey', 'abbi', 'abcunderwear', 'abd', 'abdomen', 'abdul', 'abe', 'abebookscom', 'abercrombiecom', 'aberdeen', 'abfdc', 'abil', 'abilen', 'abington', 'abiword', 'abl', 'abloy', 'abnorm', 'aboard', 'abort', 'aboveground', 'abraham', 'abras', 'abroad', 'absenc', 'absente', 'absolutelli', 'absorb', 'abstract', 'abu', 'abuelita', 'abuja', 'abvi', 'acadami', 'acai', 'acapulco', 'acarexx', 'acb', 'accentu', 'acceptedget', 'accesori', 'accessor', 'accessoriescal', 'accesssori', 'accid', 'accidenttitlemilestheft', 'acclaim', 'acco', 'accom', 'accomod', 'accompani', 'accomplish', 'accord', 'accou', 'accountemp', 'accountingcrm', 'accountpro', 'accra', 'accreditedonlineexcel', 'accucheck', 'acculab', 'accumulair', 'accuraci', 'accusquar', 'accuweath', 'acdc', 'acer', 'acertifi', 'acess', 'acet', 'acetaminophen', 'aceticketcom', 'acetonid', 'acg', 'ach', 'achil', 'achla', 'aci', 'acidophilu', 'acl', 'aclmeniscu', 'aclr', 'aclu', 'acm', 'acmoor', 'acn', 'acog', 'acolyt', 'acoust', 'acp', 'acquaviva', 'acquir', 'acr', 'acreag', 'acrobat', 'acsav', 'actionadventurerac', 'actionstev', 'activationfre', 'activelifestyl', 'activewear', 'activex', 'activti', 'actor', 'actress', 'acu', 'acupunctur', 'acupuncturist', 'acurit', 'acut', 'ada', 'adam', 'adan', 'adapet', 'adaptor', 'adchief', 'adco', 'addaphoto', 'addida', 'addl', 'addon', 'addressdoctor', 'adeco', 'adfora', 'adfre', 'adhdyour', 'adhes', 'adicross', 'adidascom', 'adidascrazyquick', 'adirondack', 'adizero', 'adjac', 'adler', 'adm', 'admin', 'administ', 'adnroid', 'adobeflash', 'adolesc', 'adomin', 'adorn', 'adr', 'adren', 'adriano', 'adselfservic', 'adt', 'advantec', 'advantix', 'advantixii', 'advenc', 'adventurebas', 'advers', 'advicecal', 'advicefre', 'adviceopen', 'advil', 'advis', 'advoc', 'advocar', 'advocatethem', 'adwar', 'adwareezula', 'adword', 'ae', 'aem', 'aemt', 'aep', 'aerat', 'aeri', 'aerial', 'aerocart', 'aerodynam', 'aerogarden', 'aeromexico', 'aeropostal', 'aerosol', 'aerospac', 'aesop', 'aesthet', 'aetvcom', 'af', 'afcc', 'aff', 'affair', 'affinia', 'affinina', 'affordablesecur', 'affordbal', 'afg', 'afghan', 'afghanistan', 'afibfind', 'afibget', 'afibsymptom', 'afiv', 'afl', 'aflac', 'aflatoxin', 'afltv', 'afn', 'aford', 'afraid', 'africanamerican', 'afro', 'afterlif', 'afternoon', 'afterschool', 'aftershav', 'ag', 'agadir', 'agawam', 'agebodi', 'aggi', 'aggreg', 'aggress', 'agil', 'ago', 'agonist', 'agra', 'agre', 'agrifab', 'agua', 'aguav', 'aguilera', 'ah', 'ahalif', 'ahh', 'ahmad', 'ahmanson', 'ahoy', 'ai', 'aidsday', 'aiff', 'aiko', 'ail', 'ailey', 'aimer', 'aimpoint', 'aip', 'airbag', 'airbend', 'airberlin', 'airberlincom', 'airbnb', 'airbrush', 'aircraft', 'airdog', 'airel', 'airfarewwii', 'airfastticket', 'airfilt', 'airforc', 'airfranc', 'airfreight', 'airfuel', 'airgun', 'airhoteltrainbreakfast', 'airless', 'airloc', 'airmax', 'airmil', 'airporthotelcruis', 'airporthotelseaport', 'airsoft', 'airtel', 'airtight', 'airtim', 'airwaysbookingbuddycom', 'airwayslimit', 'aisc', 'aisl', 'aiu', 'ajax', 'ajb', 'akc', 'akcapr', 'akiyama', 'akro', 'akron', 'akuna', 'alachua', 'alamat', 'alamo', 'alan', 'alaskan', 'albani', 'albert', 'albumcom', 'alcatraz', 'aldi', 'aldistorejob', 'aldo', 'alegria', 'alexand', 'alexandria', 'alfr', 'alga', 'algorithm', 'ali', 'alibri', 'alic', 'alicant', 'alienwar', 'aliexpress', 'alin', 'alinea', 'alison', 'aliv', 'alk', 'alla', 'allan', 'allconqu', 'allegi', 'allegra', 'allegrad', 'allerg', 'allergen', 'allergist', 'allernot', 'alley', 'allheart', 'allhow', 'allianc', 'allig', 'allin', 'allon', 'allonfour', 'alloy', 'allposterscom', 'allpurpos', 'allr', 'allseason', 'allsiz', 'allston', 'allsuit', 'alltechsolut', 'alltim', 'allur', 'allweath', 'allyson', 'almanac', 'almerimar', 'almond', 'alno', 'alnwick', 'alo', 'alon', 'aloneord', 'alongsid', 'alor', 'alot', 'alpaca', 'alpharetta', 'alpin ...
# (100000, 14216)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
import pandas as pd
df1 = pd.DataFrame(doc_vector.toarray(), columns=vectorizerX.get_feature_names())
df1.head(3)

# %% [markdown]
# #Preprocess the Query and transform it to vector

# %%
query = 'Explore Your World with Four Extraordinary Offers' #Explore Your World with Four Extraordinary Offers'
query = rem_pun(query)
query = rem_digits(query)
query =del_extra_spaces(query)
query = get_tokenized_list(query)
query = remove_stopwords(query)
q = []
for w in word_stemmer(query):
  print("w=",w)
  q.append(w)
q = ' '.join(q)
print("q=",q)
query_vector = vectorizerX.transform([q])
print("query_vector=",query_vector.shape)
# Out:
# w= explor
# w= your
# w= world
# w= four
# w= extraordinari
# w= offer
# q= explor your world four extraordinari offer
# query_vector= (1, 4555)

# %%
query_vector
# Out:
# <1x2533 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #Calculate Cosine Similarty
# ![alt text](https://i.stack.imgur.com/36r1U.png)

# %%
cosineSimilarities = cosine_similarity(doc_vector,query_vector).flatten()

# %%
cosineSimilarities
np.unique(cosineSimilarities)
# Out:
# array([0.        , 0.60540816, 0.73332467, 1.        ])

# %%
related_docs_indices = cosineSimilarities.argsort()[:-10:-1]
print(related_docs_indices)

for i in related_docs_indices:
    data = [cleaned_corpus[i]]
    print(data)
# Out:
# [    1 49320 14432 99999 33337 33328 33329 33330 33331]
# ['explor your world four extraordinari offer']
# ['extraordinari carpet clean svc for yr memphi metro area']
# ['from ordinari extraordinari watch full episod pawn star']
# ['sign get free No contract pinless']
# ['softwar surfac xbox pc more offici site plu free ship']
# ['get blind shade Up off free ship free sampl']
# ['get blind shade Up off free ship free sampl']
# ['get blind shade Up off free ship free sampl']
# ['highest rate most review onlin guarante fit free ship']
